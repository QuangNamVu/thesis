# %%
import numpy as np
import os
import pandas as pd
home_path = os.path.expanduser("~") + '/'

# %%
data_file_name = home_path + "data/ccxt/preprocessing_data/BTC_USDT_binance_1h.csv"
normalize_data = 'z_score'
normalize_data_idx = True

# %%
df = pd.read_csv(data_file_name)
df
# Out:
#        Unnamed: 0      Timestamp     Open     High      Low    Close  \
# 0               1  1503903600000  4221.04  4297.11  4207.42  4261.90
# 1               2  1503907200000  4261.90  4305.00  4239.15  4252.70
# 2               3  1503910800000  4252.70  4298.83  4226.93  4227.00
# 3               4  1503914400000  4240.00  4317.21  4240.00  4290.77
# 4               5  1503918000000  4290.77  4365.40  4288.07  4308.00
# 5               6  1503921600000  4309.00  4347.00  4271.86  4280.00
# 6               7  1503925200000  4280.00  4347.00  4279.82  4347.00
# 7               8  1503928800000  4295.32  4320.90  4279.82  4291.13
# 8               9  1503932400000  4291.13  4315.00  4271.03  4273.59
# 9              10  1503936000000  4317.20  4341.99  4273.59  4322.65
# 10             11  1503939600000  4322.65  4370.45  4313.66  4324.67
# 11             12  1503943200000  4324.64  4362.99  4307.22  4312.70
# 12             13  1503946800000  4312.69  4361.37  4312.69  4321.65
# ...

# %%
# cols = ['High', 'N_buy', '_1d_N_buy', '_1d_cost_std', 'N_sell', '_1d_cost_std', 'MA_Close_240', '_1d_N_sell', 'Volume', '_1d_Volume', 'cost_avg', '_1d_Close', 'MA_Close_24', '_1d_cost_avg', 'MA_Close_24', 'Spread_High_Low', '_1d_Spread_High_Low', '_1d_Open', 'Open', '_1d_price_avg']
cols = ['Open', 'High', 'Low', 'Close', 'Volume',
       'N_buy', 'N_sell', 'buy_amount_avg', 'buy_amount_std',
       'sell_amount_std', 'price_avg', 'price_std', 'cost_avg', 'cost_std',
       'MA_Close_24', 'MA_Close_240', 'Spread_Open_Close', 'Spread_High_Low',
       '_1d_Open', '_1d_High', '_1d_Low', '_1d_Close', '_1d_Volume',
       '_1d_N_buy', '_1d_N_sell', '_1d_buy_amount_avg', '_1d_buy_amount_std',
       '_1d_sell_amount_std', '_1d_price_avg', '_1d_price_std', '_1d_cost_avg',
       '_1d_cost_std', '_1d_MA_Close_24', '_1d_MA_Close_240',
       '_1d_Spread_Open_Close', '_1d_Spread_High_Low']

# %%
X = df[cols].values
y = df['trend'].values

N = 2160
X_train = X[:-N]
y_train = y[:-N]
X_val = X[-N:]
y_val = y[-N:]

# %%
from sklearn.decomposition import PCA
model = PCA(n_components=36).fit(X_train)

# %%
X_train = model.transform(X_train)
X_val = model.transform(X_val)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)

# %%
from sklearn.svm import SVC

clf = SVC(kernel='rbf')
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
y_train_hat = clf.predict(X_train)
cm = confusion_matrix(y_train, y_train_hat)
rp = classification_report(y_train, y_train_hat)
score = accuracy_score(y_train, y_train_hat)

print(cm)
print(rp)
print(score)
# Out:
# [[3597 3806]
#  [1480 6460]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.49      0.58      7403
#            1       0.63      0.81      0.71      7940
#
#    micro avg       0.66      0.66      0.66     15343
#    macro avg       0.67      0.65      0.64     15343
# weighted avg       0.67      0.66      0.65     15343
#
# 0.6554780681744118

# %%
y_pred = clf.predict(X_val)
cm = confusion_matrix(y_val, y_pred)
rp = classification_report(y_val, y_pred)
score = accuracy_score(y_val, y_pred)

print(cm)
print(rp)
print(score)
# Out:
# [[470 579]
#  [410 701]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.45      0.49      1049
#            1       0.55      0.63      0.59      1111
#
#    micro avg       0.54      0.54      0.54      2160
#    macro avg       0.54      0.54      0.54      2160
# weighted avg       0.54      0.54      0.54      2160
#
# 0.5421296296296296

# %% [markdown]
# # Save and Load Model:

# %%
# #Saving model
# from sklearn.externals import joblib
# joblib.dump(clf, 'checkpoint/SVM_best.joblib')

# %%
# predicted = clf.predict(X_test[picked_feature])
# print(classification_report(y_test, predicted))
